# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Social_Network_Ads.csv")

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
df.corr()
# Out:
#                       Age  EstimatedSalary  Purchased
# Age              1.000000         0.155238   0.622454
# EstimatedSalary  0.155238         1.000000   0.362083
# Purchased        0.622454         0.362083   1.000000

# %%
df1=pd.read_csv("/content/dc-wikia-data.csv")

# %%
df1
# Out:
#       page_id                          name  \
# 0        1422          Batman (Bruce Wayne)
# 1       23387         Superman (Clark Kent)
# 2        1458    Green Lantern (Hal Jordan)
# 3        1659      James Gordon (New Earth)
# 4        1576   Richard Grayson (New Earth)
# ...       ...                           ...
# 6891    66302       Nadine West (New Earth)
# 6892   283475    Warren Harding (New Earth)
# 6893   283478  William Harrison (New Earth)
# 6894   283471  William McKinley (New Earth)
# 6895   150660            Mookie (New Earth)
#
#                                    urlslug               ID            ALIGN  \
# 0             \/wiki\/Batman_(Bruce_Wayne)  Secret Identity  Good Characters
# 1            \/wiki\/Superman_(Clark_Kent)  Secret Identity  Good Characters
# 2       \/wiki\/Green_Lantern_(Hal_Jordan)  Secret Identity  Good Characters
# 3         \/wiki\/James_Gordon_(New_Earth)  Public Identity  Good Characters
# ...

# %%
df2=pd.read_csv("/content/Pengunjung_Mall.csv")

# %%
df2
# Out:
#      ID_Pelanggan  Gender  Usia  Pendapatan_Tahunan_Ribuan_USD  \
# 0               1    Pria    19                             15
# 1               2    Pria    21                             15
# 2               3  Wanita    20                             16
# 3               4  Wanita    23                             16
# 4               5  Wanita    31                             17
# ..            ...     ...   ...                            ...
# 195           196  Wanita    35                            120
# 196           197  Wanita    45                            126
# 197           198    Pria    32                            126
# 198           199    Pria    32                            137
# 199           200    Pria    30                            137
#
#      Pengeluaran_USD
# 0                 39
# 1                 81
# 2                  6
# 3                 77
# 4                 40
# ..               ...
# 195               79
# 196               28
# ...

# %%
df3=pd.read_csv("/content/YaleAdmits.csv")

# %%
df3
# Out:
#     Year Entered  Applications  Admits  AdmitRate  Matriculant  Yield  \
# 0           1986         12528    2269      0.181         1291  0.569
# 1           1987         13063    2310      0.177         1312  0.568
# 2           1988         12797    2370      0.185         1275  0.538
# 3           1989         12063    2264      0.188         1279  0.565
# 4           1990         11922    2354      0.197         1366  0.580
# 5           1991         10794    2372      0.220         1290  0.544
# 6           1992         11054    2455      0.222         1326  0.540
# 7           1993         10705    2453      0.229         1317  0.537
# 8           1994         12991    2451      0.189         1308  0.534
# 9           1995         12620    2521      0.200         1364  0.541
# 10          1996         12952    2371      0.183         1409  0.594
# 11          1997         12046    2144      0.178         1307  0.610
# ...

# %%
df4=pd.read_csv("/content/TCS.NSE.csv")

# %%
df4
# Out:
#             Date         Open         High          Low        Close  \
# 0     2015-01-01  1283.500000  1283.500000  1270.500000  1272.775024
# 1     2015-01-02  1275.500000  1295.474976  1275.300049  1289.724976
# 2     2015-01-05  1290.500000  1299.949951  1262.324951  1270.125000
# 3     2015-01-06  1264.550049  1264.550049  1220.000000  1223.300049
# 4     2015-01-07  1235.000000  1239.574951  1203.724976  1208.849976
# ...          ...          ...          ...          ...          ...
# 1661  2021-09-24  3890.000000  3944.399902  3855.000000  3871.300049
# 1662  2021-09-27  3900.000000  3904.000000  3802.899902  3836.949951
# 1663  2021-09-28  3850.000000  3850.000000  3751.250000  3779.149902
# 1664  2021-09-29  3759.800049  3806.000000  3722.149902  3791.899902
# 1665  2021-09-30  3805.000000  3805.000000  3750.100098  3775.550049
#
#         Adj Close     Volume
# 0     1114.909302   366830.0
# 1     1129.757202   925740.0
# 2     1112.587769  1754242.0
# ...

# %%
df5=pd.read_csv("/content/nutrition-booklet.csv")

# %%
df5
# Out:
#             Products Avg. Portio n Weigh\nt No of\nservi ngs Total Energy  \
# 0                NaN                      g              NaN    Per Serve
# 1     Snacks non Veg                      g               no         Kcal
# 2    Hot\nWings 2 pc                     75                1        267.1
# 3     Hot Wings 4 Pc                    155                1        534.3
# 4                NaN                    NaN              NaN          NaN
# ..               ...                    ...              ...          ...
# 113        Pepsi Pet                    500                2        143.3
# 114      Pepsi Black                    300              1.5          0.0
# 115         Red Bull                    250                1        112.5
# 116              NaN                    NaN              NaN          NaN
# 117              NaN                    NaN              NaN          NaN
#
#     Carbo hydra te   Protei n   Tot al Fat         %\nof RD A   Tra ns Fat  \
# ...
